# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from statistics import mean, stdev
from sklearn import preprocessing

# %%
# Load dataset
data = pd.read_csv("brain_stroke.csv")
data.head(5)
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %% [markdown]
# # Check For Missing Values

# %%
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# # Check Data Types of All Attributes

# %%
# Check data types of each column
print(data.dtypes)
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
# 2. Encoding categorical variables
label_cols = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
for col in label_cols:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])

# %%
data
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          1
# 1          1  80.0             0              1             1          1
# 2          0  49.0             0              0             1          1
# 3          0  79.0             1              0             1          2
# 4          1  81.0             0              0             1          1
# ...      ...   ...           ...            ...           ...        ...
# 4976       1  41.0             0              0             0          1
# 4977       1  40.0             0              0             1          1
# 4978       0  45.0             1              0             1          0
# 4979       1  40.0             0              0             1          1
# 4980       0  80.0             1              0             1          1
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0                  1             228.69  36.6               1       1
# 1                  0             105.92  32.5               2       1
# 2                  1             171.23  34.4               3       1
# 3                  0             174.12  24.0               2       1
# 4                  1             186.21  29.0               1       1
# ...              ...                ...   ...             ...     ...
# 4976               0              70.15  29.8               1       0
# 4977               1             191.15  31.1               3       0
# 4978               0              95.02  31.8               3       0
# 4979               0              83.94  30.0               3       0
# 4980               1              83.75  29.1               2       0
#
# [4981 rows x 11 columns]

# %%
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns.tolist()
min_values = data[numerical_cols].min()
max_values = data[numerical_cols].max()

# Calculate the range
range_values = max_values - min_values

# Combine results into a DataFrame for better visualization
range_df = pd.DataFrame({
    'Min': min_values,
    'Max': max_values,
    'Range': range_values
})

print(range_df)
# Out:
#                      Min     Max   Range
# age                 0.08   82.00   81.92
# hypertension        0.00    1.00    1.00
# heart_disease       0.00    1.00    1.00
# avg_glucose_level  55.12  271.74  216.62
# bmi                14.00   48.90   34.90
# stroke              0.00    1.00    1.00

# %%
# 3. Feature Scaling (for continuous variables)
scaler = StandardScaler()
data[['age', 'avg_glucose_level', 'bmi']] = scaler.fit_transform(data[['age', 'avg_glucose_level', 'bmi']])

# %%
# Descriptive statistics for numerical features
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Descriptive statistics for numerical features:")
print(data[numerical_cols].describe())

# Visualizing distributions of numerical features
for col in numerical_cols:
    plt.figure(figsize=(8, 5))
    sns.histplot(data[col], bins=30, kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()
# Out:
# Descriptive statistics for numerical features:
#                 age  hypertension  heart_disease  avg_glucose_level  \
# count  4.981000e+03   4981.000000    4981.000000       4.981000e+03
# mean   2.853012e-18      0.096165       0.055210       1.169735e-16
# std    1.000100e+00      0.294848       0.228412       1.000100e+00
# min   -1.912575e+00      0.000000       0.000000      -1.127637e+00
# 25%   -8.128627e-01      0.000000       0.000000      -6.370761e-01
# 50%    6.973111e-02      0.000000       0.000000      -3.126979e-01
# 75%    7.758062e-01      0.000000       0.000000       1.756443e-01
# max    1.702530e+00      1.000000       1.000000       3.678574e+00
#
#                 bmi       stroke
# count  4.981000e+03  4981.000000
# mean  -6.219567e-16     0.049789
# std    1.000100e+00     0.217531
# min   -2.135293e+00     0.000000
# 25%   -7.066756e-01     0.000000
# 50%   -5.864298e-02     0.000000
# 75%    6.041176e-01     0.000000
# max    3.004784e+00     1.000000

# %%
# Check for imbalance in the target variable
plt.figure(figsize=(8, 5))
sns.countplot(x='stroke', data=data)
plt.title("Distribution of Stroke")
plt.xlabel("Stroke")
plt.ylabel("Count")
plt.xticks([0, 1], ['No Stroke', 'Stroke'])
plt.show()

# %%
X = data.drop('stroke', axis=1)
y = data['stroke']

# %%
X
# Out:
#       gender       age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  1.040584             0              1             1          1
# 1          1  1.614270             0              1             1          1
# 2          0  0.246250             0              0             1          1
# 3          0  1.570141             1              0             1          2
# 4          1  1.658400             0              0             1          1
# ...      ...       ...           ...            ...           ...        ...
# 4976       1 -0.106788             0              0             0          1
# 4977       1 -0.150917             0              0             1          1
# 4978       0  0.069731             1              0             1          0
# 4979       1 -0.150917             0              0             1          1
# 4980       0  1.614270             1              0             1          1
#
#       Residence_type  avg_glucose_level       bmi  smoking_status
# 0                  1           2.723411  1.193238               1
# 1                  0          -0.000523  0.589390               2
# 2                  1           1.448529  0.869222               3
# 3                  0           1.512650 -0.662492               2
# 4                  1           1.780895  0.073909               1
# ...              ...                ...       ...             ...
# 4976               0          -0.794162  0.191733               1
# 4977               1           1.890500  0.383197               3
# 4978               0          -0.242364  0.486294               3
# 4979               0          -0.488199  0.221189               3
# 4980               1          -0.492415  0.088637               2
#
# [4981 rows x 10 columns]

# %% [markdown]
# **Logistic Regression With Stratified Cross Validation**

# %%
# Feature Scaling for Input Features
scaler = preprocessing.MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Create Classifier Object
lr = LogisticRegression()

# Create StratifiedKFold Object
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
lst_accu_stratified = []

# Stratified K-Fold Cross Validation
for train_index, test_index in skf.split(X_scaled, y):
    X_train_fold, X_test_fold = X_scaled[train_index], X_scaled[test_index]
    y_train_fold, y_test_fold = y[train_index], y[test_index]

    # Fit the model on the training fold
    lr.fit(X_train_fold, y_train_fold)

    # Append the accuracy of the fold
    lst_accu_stratified.append(lr.score(X_test_fold, y_test_fold))

# Print the output for cross-validation
print('List of possible accuracy:', lst_accu_stratified)
print('\nMaximum Accuracy That can be obtained from this model is:', max(lst_accu_stratified)*100, '%')
print('\nMinimum Accuracy:', min(lst_accu_stratified)*100, '%')
print('\nOverall Accuracy:', mean(lst_accu_stratified)*100, '%')
print('\nStandard Deviation is:', stdev(lst_accu_stratified))
# Out:
# List of possible accuracy: [0.9498997995991983, 0.9497991967871486, 0.9497991967871486, 0.9497991967871486, 0.9497991967871486, 0.9497991967871486, 0.9497991967871486, 0.9497991967871486, 0.9518072289156626, 0.9518072289156626]
#
# Maximum Accuracy That can be obtained from this model is: 95.18072289156626 %
#
# Minimum Accuracy: 94.97991967871486 %
#
# Overall Accuracy: 95.02108634940564 %
#
# Standard Deviation is: 0.0008419430046900221

# %% [markdown]
# **Train Test Split Without Stratification**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %% [markdown]
# **Logistic Regression With Grid Search**

# %%
from sklearn.model_selection import GridSearchCV
# Logistic Regression
lr = LogisticRegression()
grid={"C":np.logspace(-3,3,7), "penalty":["l1","l2"]}
grid_search =  GridSearchCV(estimator=lr, param_grid=grid, scoring='accuracy')

grid_search.fit(X_train, y_train)
print("Best Hyperparameters:", grid_search.best_params_)
print("Best Accuracy:", grid_search.best_score_)

# Evaluate the best model on the test data
best_model = grid_search.best_estimator_
test_accuracy = best_model.score(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Best Hyperparameters: {'C': 0.001, 'penalty': 'l2'}
# Best Accuracy: 0.9512334894122579
# Test Accuracy: 0.9478260869565217
# C:\Users\micah\school\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 35 fits failed out of a total of 70.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\micah\school\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\micah\school\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\micah\school\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\micah\school\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\micah\school\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan 0.95123349        nan 0.95123349        nan 0.95123349
#         nan 0.95123349        nan 0.95123349        nan 0.95123349
#         nan 0.95123349]
#   warnings.warn(

# %% [markdown]
# **K Nearest Neighbor Classifier With Stratified Cross Validation**

# %%
# Feature Scaling for Input Features
scaler = preprocessing.MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Create Classifier Object
kc = KNeighborsClassifier()

# Create StratifiedKFold Object
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
lst_accu_stratified = []

# Stratified K-Fold Cross Validation
for train_index, test_index in skf.split(X_scaled, y):
    X_train_fold, X_test_fold = X_scaled[train_index], X_scaled[test_index]
    y_train_fold, y_test_fold = y[train_index], y[test_index]

    # Fit the model on the training fold
    kc.fit(X_train_fold, y_train_fold)

    # Append the accuracy of the fold
    lst_accu_stratified.append(kc.score(X_test_fold, y_test_fold))

# Print the output for cross-validation
print('List of possible accuracy:', lst_accu_stratified)
print('\nMaximum Accuracy That can be obtained from this model is:', max(lst_accu_stratified)*100, '%')
print('\nMinimum Accuracy:', min(lst_accu_stratified)*100, '%')
print('\nOverall Accuracy:', mean(lst_accu_stratified)*100, '%')
print('\nStandard Deviation is:', stdev(lst_accu_stratified))
# Out:
# List of possible accuracy: [0.9438877755511023, 0.9457831325301205, 0.9477911646586346, 0.9497991967871486, 0.9497991967871486, 0.9457831325301205, 0.9518072289156626, 0.9497991967871486, 0.9437751004016064, 0.9457831325301205]
#
# Maximum Accuracy That can be obtained from this model is: 95.18072289156626 %
#
# Minimum Accuracy: 94.37751004016064 %
#
# Overall Accuracy: 94.74008257478813 %
#
# Standard Deviation is: 0.002792121938604873

# %% [markdown]
# **K Nearest Neighbors With Grid Search**

# %%
# K-Nearest Neighbors
kc = KNeighborsClassifier()
k_range = list(range(1, 31))
grid = dict()
grid['n_neighbors'] = [10, 50, 100, 500]
grid['weights']= ['uniform', 'distance']
grid['metric']= ['euclidean', 'manhattan']
grid = GridSearchCV(kc, param_grid = grid, cv=10, scoring='accuracy', return_train_score=False)
grid.fit(X_train, y_train)

print("Best Hyperparameters:", grid.best_params_)
print("Best Accuracy:", grid.best_score_)

# Evaluate the best model on the test data
best_model = grid.best_estimator_
test_accuracy = best_model.score(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Best Hyperparameters: {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# Best Accuracy: 0.9512334090834239
# Test Accuracy: 0.9471571906354515

# %% [markdown]
# **Random Forest Classifier With Stratified Cross Validation**

# %%
# Feature Scaling for Input Features
scaler = preprocessing.MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Create Classifier Object
Rc = RandomForestClassifier()

# Create StratifiedKFold Object
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
lst_accu_stratified = []

# Stratified K-Fold Cross Validation
for train_index, test_index in skf.split(X_scaled, y):
    X_train_fold, X_test_fold = X_scaled[train_index], X_scaled[test_index]
    y_train_fold, y_test_fold = y[train_index], y[test_index]

    # Fit the model on the training fold
    Rc.fit(X_train_fold, y_train_fold)

    # Append the accuracy of the fold
    lst_accu_stratified.append(Rc.score(X_test_fold, y_test_fold))

# Print the output for cross-validation
print('List of possible accuracy:', lst_accu_stratified)
print('\nMaximum Accuracy That can be obtained from this model is:', max(lst_accu_stratified)*100, '%')
print('\nMinimum Accuracy:', min(lst_accu_stratified)*100, '%')
print('\nOverall Accuracy:', mean(lst_accu_stratified)*100, '%')
print('\nStandard Deviation is:', stdev(lst_accu_stratified))
# Out:
# List of possible accuracy: [0.9478957915831663, 0.9477911646586346, 0.9477911646586346, 0.9497991967871486, 0.9497991967871486, 0.9497991967871486, 0.9477911646586346, 0.9477911646586346, 0.9518072289156626, 0.9437751004016064]
#
# Maximum Accuracy That can be obtained from this model is: 95.18072289156626 %
#
# Minimum Accuracy: 94.37751004016064 %
#
# Overall Accuracy: 94.8404036989642 %
#
# Standard Deviation is: 0.0021241716077563693

# %% [markdown]
# **Random Forest With Grid Search**

# %%
# Random Forest
rf_grid = RandomForestClassifier()
gr_space = {
    'max_depth': [3,5,7,10],
    'n_estimators': [100, 200, 300, 400, 500],
    'max_features': [10, 20, 30 , 40],
    'min_samples_leaf': [1, 2, 4]
}

grid = GridSearchCV(rf_grid, gr_space, cv = 3, scoring='accuracy', verbose = 3)
model_grid = grid.fit(X_train, y_train)

print("Best Hyperparameters:", model_grid.best_params_)
print("Best Accuracy:", model_grid.best_score_)

# Evaluate the best model on the test data
best_model = model_grid.best_estimator_
test_accuracy = best_model.score(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Fitting 3 folds for each of 240 candidates, totalling 720 fits
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=100;, score=0.952 total time=   0.1s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.1s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=200;, score=0.952 total time=   0.4s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=300;, score=0.952 total time=   0.7s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=400;, score=0.952 total time=   0.9s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=500;, score=0.952 total time=   1.1s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=100;, score=0.952 total time=   0.1s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.1s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.1s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=200;, score=0.952 total time=   0.4s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=300;, score=0.952 total time=   0.6s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.6s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   0.9s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 1/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.2s
# [CV 2/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=3, max_features=10, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=100;, score=0.952 total time=   0.1s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.1s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.1s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=200;, score=0.952 total time=   0.4s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=100;, score=0.952 total time=   0.1s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=200;, score=0.952 total time=   0.5s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.8s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=300;, score=0.952 total time=   1.3s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   1.0s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   1.0s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=400;, score=0.952 total time=   1.4s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=500;, score=0.952 total time=   1.2s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=100;, score=0.952 total time=   0.1s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=200;, score=0.952 total time=   0.4s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=300;, score=0.952 total time=   0.7s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   0.9s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 1/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.2s
# [CV 2/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=3, max_features=20, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.6s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=400;, score=0.952 total time=   0.9s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=200;, score=0.952 total time=   0.4s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=300;, score=0.952 total time=   0.7s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=400;, score=0.952 total time=   1.0s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=500;, score=0.952 total time=   1.2s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=200;, score=0.952 total time=   0.4s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=300;, score=0.952 total time=   0.7s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   1.0s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 1/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.2s
# [CV 2/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=3, max_features=30, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.1s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   1.0s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.6s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=100;, score=0.952 total time=   0.1s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.1s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.1s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=200;, score=0.952 total time=   0.4s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=300;, score=0.952 total time=   1.0s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   1.0s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   1.0s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=400;, score=0.952 total time=   1.4s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=500;, score=0.952 total time=   1.9s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=200;, score=0.952 total time=   0.4s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=300;, score=0.952 total time=   0.7s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   0.9s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   1.0s
# [CV 1/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.2s
# [CV 2/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=3, max_features=40, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=200;, score=0.952 total time=   0.5s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=500;, score=0.952 total time=   1.5s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=200;, score=0.952 total time=   0.5s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=300;, score=0.952 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   1.2s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.4s
# [CV 2/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=10, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=200;, score=0.952 total time=   0.5s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=300;, score=0.952 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   1.2s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.4s
# [CV 2/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=20, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=400;, score=0.952 total time=   1.2s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=500;, score=0.952 total time=   1.5s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=200;, score=0.952 total time=   0.5s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=300;, score=0.952 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=200;, score=0.952 total time=   0.5s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=300;, score=0.952 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   1.2s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.5s
# [CV 2/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=30, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=200;, score=0.952 total time=   0.5s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=200;, score=0.952 total time=   0.6s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=200;, score=0.952 total time=   0.5s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=300;, score=0.952 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   1.1s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   1.1s
# [CV 1/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.4s
# [CV 2/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=5, max_features=40, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.4s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=100;, score=0.952 total time=   0.3s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=100;, score=0.952 total time=   0.3s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=200;, score=0.952 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=300;, score=0.952 total time=   1.0s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   1.0s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=300;, score=0.952 total time=   1.0s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=400;, score=0.953 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=400;, score=0.952 total time=   1.2s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=500;, score=0.952 total time=   1.6s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.6s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.7s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=100;, score=0.953 total time=   0.3s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=200;, score=0.952 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=300;, score=0.952 total time=   0.9s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=400;, score=0.952 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.6s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.5s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=2, n_estimators=500;, score=0.952 total time=   1.6s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=200;, score=0.952 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=300;, score=0.952 total time=   0.9s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=300;, score=0.952 total time=   1.0s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   1.2s
# [CV 1/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.6s
# [CV 2/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.6s
# [CV 3/3] END max_depth=7, max_features=10, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.6s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=100;, score=0.952 total time=   0.3s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=200;, score=0.953 total time=   0.7s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=200;, score=0.950 total time=   0.6s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=300;, score=0.953 total time=   1.0s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   1.0s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=300;, score=0.952 total time=   1.0s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=400;, score=0.952 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=500;, score=0.953 total time=   1.7s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=500;, score=0.950 total time=   1.6s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=1, n_estimators=500;, score=0.952 total time=   1.7s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=100;, score=0.952 total time=   0.3s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=100;, score=0.952 total time=   0.3s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=200;, score=0.952 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=200;, score=0.952 total time=   0.6s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=300;, score=0.953 total time=   0.9s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=300;, score=0.952 total time=   0.9s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.6s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=500;, score=0.951 total time=   1.6s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=2, n_estimators=500;, score=0.952 total time=   1.6s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=100;, score=0.952 total time=   0.3s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=200;, score=0.952 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=200;, score=0.952 total time=   0.6s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=300;, score=0.952 total time=   0.9s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=300;, score=0.951 total time=   1.0s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   1.2s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=400;, score=0.951 total time=   1.4s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=400;, score=0.952 total time=   1.4s
# [CV 1/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.6s
# [CV 2/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=500;, score=0.951 total time=   1.6s
# [CV 3/3] END max_depth=7, max_features=20, min_samples_leaf=4, n_estimators=500;, score=0.952 total time=   1.6s
# [CV 1/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=100;, score=0.952 total time=   0.3s
# [CV 2/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=200;, score=0.952 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 1/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=300;, score=0.952 total time=   0.9s
# [CV 2/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=300;, score=0.952 total time=   1.0s
# [CV 1/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=400;, score=0.952 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=400;, score=0.952 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=500;, score=0.952 total time=   1.6s
# [CV 2/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.6s
# [CV 3/3] END max_depth=7, max_features=30, min_samples_leaf=1, n_estimators=500;, score=0.951 total time=   1.6s
# [CV 1/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 3/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 3/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=200;, score=0.951 total time=   0.6s
# [CV 1/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=300;, score=0.952 total time=   0.9s
# [CV 2/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=300;, score=0.951 total time=   0.9s
# [CV 3/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=300;, score=0.950 total time=   0.9s
# [CV 1/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=400;, score=0.953 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=30, min_samples_leaf=2, n_estimators=400;, score=0.951 total time=   1.3s

# %% [markdown]
# **Gradient Boosting Classifier With Stratified Cross Validation**

# %%
# Feature Scaling for Input Features
scaler = preprocessing.MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Create Classifier Object
Gc = GradientBoostingClassifier()

# Create StratifiedKFold Object
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
lst_accu_stratified = []

# Stratified K-Fold Cross Validation
for train_index, test_index in skf.split(X_scaled, y):
    X_train_fold, X_test_fold = X_scaled[train_index], X_scaled[test_index]
    y_train_fold, y_test_fold = y[train_index], y[test_index]

    # Fit the model on the training fold
    Gc.fit(X_train_fold, y_train_fold)

    # Append the accuracy of the fold
    lst_accu_stratified.append(Gc.score(X_test_fold, y_test_fold))

# Print the output for cross-validation
print('List of possible accuracy:', lst_accu_stratified)
print('\nMaximum Accuracy That can be obtained from this model is:', max(lst_accu_stratified)*100, '%')
print('\nMinimum Accuracy:', min(lst_accu_stratified)*100, '%')
print('\nOverall Accuracy:', mean(lst_accu_stratified)*100, '%')
print('\nStandard Deviation is:', stdev(lst_accu_stratified))

# %% [markdown]
# **Gradient Boosting Classifier with Grid Search**

# %%
# Gradient Boosting Classifier
model = GradientBoostingClassifier()
grid = dict()
grid['n_estimators'] = [10, 50, 100, 500]
grid['learning_rate'] = [0.0001, 0.001, 0.01, 0.1, 1.0]
grid['subsample'] = [0.5, 0.7, 1.0]
grid['max_depth'] = [3, 7, 9]
grid['min_samples_leaf'] = [1, 2, 4]

# define the grid search procedure
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1,cv = 5)

grid_search.fit(X_train, y_train)
print("Best Hyperparameters:", grid_search.best_params_)
print("Best Accuracy:", grid_search.best_score_)

# Evaluate the best model on the test data
best_model = grid_search.best_estimator_
test_accuracy = best_model.score(X_test, y_test)
print("Test Accuracy:", test_accuracy)

# %% [markdown]
# **Decision Tree Classifier With Stratified Cross Validation**

# %%
# Feature Scaling for Input Features
scaler = preprocessing.MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Create Classifier Object
DT = DecisionTreeClassifier()

# Create StratifiedKFold Object
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
lst_accu_stratified = []

# Stratified K-Fold Cross Validation
for train_index, test_index in skf.split(X_scaled, y):
    X_train_fold, X_test_fold = X_scaled[train_index], X_scaled[test_index]
    y_train_fold, y_test_fold = y[train_index], y[test_index]

    # Fit the model on the training fold
    DT.fit(X_train_fold, y_train_fold)

    # Append the accuracy of the fold
    lst_accu_stratified.append(DT.score(X_test_fold, y_test_fold))

# Print the output for cross-validation
print('List of possible accuracy:', lst_accu_stratified)
print('\nMaximum Accuracy That can be obtained from this model is:', max(lst_accu_stratified)*100, '%')
print('\nMinimum Accuracy:', min(lst_accu_stratified)*100, '%')
print('\nOverall Accuracy:', mean(lst_accu_stratified)*100, '%')
print('\nStandard Deviation is:', stdev(lst_accu_stratified))

# %% [markdown]
# **Decision Tree With Grid Search**

# %%
param_grid = {
    'max_depth': [3, 5, 10],
    'min_samples_split': [2, 5, 10],
    'criterion': ['gini', 'entropy'],
    'min_samples_leaf': [1, 2, 4]
}
DT = DecisionTreeClassifier()
grid_search = GridSearchCV(estimator=DT,
                           param_grid=param_grid,
                           cv=5,
                           scoring='accuracy')
# Decision Tree Classifier

grid_search.fit(X_train, y_train)
print("Best Hyperparameters:", grid_search.best_params_)
print("Best Accuracy:", grid_search.best_score_)

# Evaluate the best model on the test data
best_model = grid_search.best_estimator_
test_accuracy = best_model.score(X_test, y_test)
print("Test Accuracy:", test_accuracy)

# %%
import matplotlib.pyplot as plt

# Define the data
models = ['Random Forest', 'K Nearest Neighbors', 'Decision Tree', 'Logistic Regression', 'Gradient Boost']
accuracy = [0.95, 0.95, 0.91, 0.95, 0.95]

plt.figure(figsize=(8, 5))
plt.barh(models, accuracy, color='royalblue')
plt.xlabel('Accuracy')
plt.ylabel('Models')
plt.title('Average CV Mean Accuracy')
plt.xlim(0, 1)
plt.tight_layout()
plt.show()

# %% [markdown]
# Analysis: The models that were used, like Random Forest, K Nearest Neighbors, Logistic Regression, and Gradient Boost, all got a high accuracy of 0.95. The Decision Tree was still good but a little lower, at 0.91.
#
# Why Some Models Performed Better: Random Forest: This model combines many decision trees, so it reduces overfitting and gives better results. It can handle more complex data, which is why it did so well here.
#
# K Nearest Neighbors (KNN): KNN also worked well, which could mean the data is easy to classify. It might not have complicated patterns, so KNN could classify it without much trouble.
#
# Logistic Regression: Even though it is a simple model, it still performed great. This might be because the data is mostly linearly separable, making it easy for Logistic Regression to classify the strokes.
#
# Gradient Boost: Similar to Random Forest, it creates models step by step to fix errors from before. Its high accuracy shows it learned well from the mistakes of other models and made stronger predictions
#
# Decision Tree: Decision Trees are good at explaining the results but sometimes overfit, which might be why it did not do as well as the others.
#
# XGBoost: XGBoost worked well, but not as good as other models. This is likely due to the effective handling of data features, robust training methods, and the algorithm’s capability to capture complex patterns.
#
# Conclusion: The four models that performed the best likely show that the dataset is good and the features are strong. Random Forest and Gradient Boost might be more reliable in the long run because they are less likely to overfit. All models, except for Decision Tree, performed very similarly, meaning the data might not need very complex models to classify it well.The utilization of grid search is optimal only in the case of the decision tree, where its implementation resulted in a 4% increase in performance.Our analysis concluded that the random forest was the most optimal model.
